# %%
import numpy as np
import pandas as pd
# Out:
# No of Features: 561

# %%
def Remove(duplicate): 
    final_list = [] 
    for num in duplicate: 
        if num not in final_list: 
            final_list.append(num) 
    return final_list 
      
# Driver Code 
duplicate = features_data 
print(len(Remove(duplicate)))
#final_list
new_list=[]
new_list=Remove(duplicate)
# Out:
# 477

# %%
features_level  = pd.read_csv('C:/DataScince/Capstone_P2/UCI HAR Dataset/UCI HAR Dataset/features.txt',encoding='utf-8',sep='\s+',header=None,names=['id','features'])
x=features_level[features_level['features'].duplicated()==True]
features_level['features_name']=features_level['features'].map(str)+features_level['id'].map(str)
x=features_level[features_level['features'].duplicated()==True]
x.head()
# Out:
#       id                      features                    features_name
# 316  317    fBodyAcc-bandsEnergy()-1,8    fBodyAcc-bandsEnergy()-1,8317
# 317  318   fBodyAcc-bandsEnergy()-9,16   fBodyAcc-bandsEnergy()-9,16318
# 318  319  fBodyAcc-bandsEnergy()-17,24  fBodyAcc-bandsEnergy()-17,24319
# 319  320  fBodyAcc-bandsEnergy()-25,32  fBodyAcc-bandsEnergy()-25,32320
# 320  321  fBodyAcc-bandsEnergy()-33,40  fBodyAcc-bandsEnergy()-33,40321

# %%
X_train = pd.read_csv('C:/DataScince/Capstone_P2/UCI HAR Dataset/UCI HAR Dataset/train/X_train.txt',sep='\s+',header=None,names=features_level.features_name.tolist())

X_train.head()
# Out:
#    tBodyAcc-mean()-X1  tBodyAcc-mean()-Y2  tBodyAcc-mean()-Z3  \
# 0            0.288585           -0.020294           -0.132905
# 1            0.278419           -0.016411           -0.123520
# 2            0.279653           -0.019467           -0.113462
# 3            0.279174           -0.026201           -0.123283
# 4            0.276629           -0.016570           -0.115362
#
#    tBodyAcc-std()-X4  tBodyAcc-std()-Y5  tBodyAcc-std()-Z6  tBodyAcc-mad()-X7  \
# 0          -0.995279          -0.983111          -0.913526          -0.995112
# 1          -0.998245          -0.975300          -0.960322          -0.998807
# 2          -0.995380          -0.967187          -0.978944          -0.996520
# 3          -0.996091          -0.983403          -0.990675          -0.997099
# 4          -0.998139          -0.980817          -0.990482          -0.998321
#
#    tBodyAcc-mad()-Y8  tBodyAcc-mad()-Z9  tBodyAcc-max()-X10  ...  \
# ...

# %%
# add subject column to the dataframe
X_train['subject'] = pd.read_csv('C:/DataScince/Capstone_P2/UCI HAR Dataset/UCI HAR Dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('C:/DataScince/Capstone_P2/UCI HAR Dataset/UCI HAR Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
#       tBodyAcc-mean()-X1  tBodyAcc-mean()-Y2  tBodyAcc-mean()-Z3  \
# 5307             0.27541           -0.021845           -0.102862
#
#       tBodyAcc-std()-X4  tBodyAcc-std()-Y5  tBodyAcc-std()-Z6  \
# 5307          -0.996698          -0.976225           -0.98207
#
#       tBodyAcc-mad()-X7  tBodyAcc-mad()-Y8  tBodyAcc-mad()-Z9  \
# 5307          -0.997559          -0.973691          -0.982399
#
#       tBodyAcc-max()-X10  ...  angle(tBodyAccMean,gravity)555  \
# 5307            -0.93458  ...                        0.006655
#
#       angle(tBodyAccJerkMean),gravityMean)556  \
# 5307                                 -0.08496
#
#       angle(tBodyGyroMean,gravityMean)557  \
# 5307                             -0.18849
#
#       angle(tBodyGyroJerkMean,gravityMean)558  angle(X,gravityMean)559  \
# 5307                                 0.722634                -0.844695
#
#       angle(Y,gravityMean)560  angle(Z,gravityMean)561  subject  Activity  \
# ...

# %%
train.columns
# Out:
# Index(['tBodyAcc-mean()-X1', 'tBodyAcc-mean()-Y2', 'tBodyAcc-mean()-Z3',
#        'tBodyAcc-std()-X4', 'tBodyAcc-std()-Y5', 'tBodyAcc-std()-Z6',
#        'tBodyAcc-mad()-X7', 'tBodyAcc-mad()-Y8', 'tBodyAcc-mad()-Z9',
#        'tBodyAcc-max()-X10',
#        ...
#        'angle(tBodyAccMean,gravity)555',
#        'angle(tBodyAccJerkMean),gravityMean)556',
#        'angle(tBodyGyroMean,gravityMean)557',
#        'angle(tBodyGyroJerkMean,gravityMean)558', 'angle(X,gravityMean)559',
#        'angle(Y,gravityMean)560', 'angle(Z,gravityMean)561', 'subject',
#        'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %%
train.shape
# Out:
# (7352, 564)

# %%
#obtaining test data 
X_test = pd.read_csv('C:/DataScince/Capstone_P2/UCI HAR Dataset/UCI HAR Dataset/test/X_test.txt', sep='\s+', header=None, names=features_level.features_name.tolist())

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('C:/DataScince/​C:/DataScince/Capstone_P2Capstone_P2/UCI HAR Dataset/UCI HAR Dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('C:/DataScince/Capstone_P2/UCI HAR Dataset/UCI HAR Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#      tBodyAcc-mean()-X1  tBodyAcc-mean()-Y2  tBodyAcc-mean()-Z3  \
# 538            0.278612           -0.016745           -0.107835
#
#      tBodyAcc-std()-X4  tBodyAcc-std()-Y5  tBodyAcc-std()-Z6  \
# 538          -0.994232          -0.990099          -0.991728
#
#      tBodyAcc-mad()-X7  tBodyAcc-mad()-Y8  tBodyAcc-mad()-Z9  \
# 538          -0.995036          -0.990372          -0.991913
#
#      tBodyAcc-max()-X10  ...  angle(tBodyAccMean,gravity)555  \
# 538           -0.938161  ...                       -0.507305
#
#      angle(tBodyAccJerkMean),gravityMean)556  \
# 538                                 0.950027
#
#      angle(tBodyGyroMean,gravityMean)557  \
# 538                             0.182156
#
#      angle(tBodyGyroJerkMean,gravityMean)558  angle(X,gravityMean)559  \
# 538                                -0.461675                 0.560413
#
#      angle(Y,gravityMean)560  angle(Z,gravityMean)561  subject  Activity  \
# ...

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# Data Cleaning

# %%
#1.Check duplicates
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
#2.Checking Null values
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# Data is lready clean . so we can procced with further step

# %%
#checking for data imbalance
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train['ActivityName'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# By looking above graphs we can say there is no data imbalance for all category

# %%
'''
Just making the column names more readable.
'''

columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX1', 'tBodyAccmeanY2', 'tBodyAccmeanZ3', 'tBodyAccstdX4',
#        'tBodyAccstdY5', 'tBodyAccstdZ6', 'tBodyAccmadX7', 'tBodyAccmadY8',
#        'tBodyAccmadZ9', 'tBodyAccmaxX10',
#        ...
#        'angletBodyAccMeangravity555', 'angletBodyAccJerkMeangravityMean556',
#        'angletBodyGyroMeangravityMean557',
#        'angletBodyGyroJerkMeangravityMean558', 'angleXgravityMean559',
#        'angleYgravityMean560', 'angleZgravityMean561', 'subject', 'Activity',
#        'ActivityName'],
#       dtype='object', length=564)

# %%
train.to_csv('C:/DataScince/Capstone_P2/UCI_HAR_dataset/csv_files/train.csv', index=False)
test.to_csv('C:/DataScince/Capstone_P2/UCI_HAR_dataset/csv_files/test.csv', index=False)

# %% [markdown]
# Exploratory Data Analysis
# 1. Featuring Engineering from Domain Knowledge
# Static and Dynamic Activities
#
# In static activities (sit, stand, lie down), motion information will not be very useful.
# In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.
# 2. Stationary and Moving activities are completely different

# %%
train=pd.read_csv('C:/DataScince/Capstone_P2/UCI_HAR_dataset/csv_files/csv_files/train.csv')
test=pd.read_csv('C:/DataScince/Capstone_P2/UCI_HAR_dataset/csv_files/csv_files/test.csv')

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple"))
plt.show()

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Observations:
#
# <li>If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# We can classify 75% the Acitivity labels with some errors.</li>

# %%
#4. Position of GravityAccelerationComponants also matters
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# Observations:
#
# If angleX,gravityMean > 0 then Activity is Laying.
# We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# ### Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.587s...
# [t-SNE] Computed neighbors for 7352 samples in 98.010s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635855
# [t-SNE] Computed conditional probabilities in 0.104s
# [t-SNE] Iteration 50: error = 124.7738495, gradient norm = 0.0266984 (50 iterations in 11.509s)
# ...

# %% [markdown]
# We can see that even with different perplexities, all the different Activity names are clustered pretty well, except 2, 'STANDING ' and 'SITTING'.
